# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate fake data for the three methods
# x-axis: performance on fine-tuning task
# y-axis: safety (refusal rate)

# Original model point
original_x = 0.1
original_y = 0.95

# Full-fine tuning data
full_x = np.array([0.2, 0.3, 0.5, 0.65, 0.8, 0.9, 0.95])
full_y = np.array([0.93, 0.9, 0.85, 0.75, 0.6, 0.45, 0.35])

# LoRA data
lora_x = np.array([0.25, 0.4, 0.55, 0.7, 0.85])
lora_y = np.array([0.92, 0.88, 0.82, 0.75, 0.65])

# RLHF data
rlhf_x = np.array([0.35, 0.5, 0.65, 0.75, 0.85, 0.95])
rlhf_y = np.array([0.8, 0.7, 0.6, 0.55, 0.45, 0.35])

# Create figure and axis
plt.figure(figsize=(10, 8))
plt.rcParams.update({'font.size': 14})

# Plot the data points with lines
plt.plot(full_x, full_y, 'r-', alpha=0.7)
plt.scatter(full_x, full_y, color='red', s=80, zorder=5)

plt.plot(lora_x, lora_y, 'y-', alpha=0.7)
plt.scatter(lora_x, lora_y, color='gold', s=80, zorder=5)

plt.plot(rlhf_x, rlhf_y, 'g-', alpha=0.7)
plt.scatter(rlhf_x, rlhf_y, color='green', s=80, zorder=5)

# Plot the original model point with a special marker
plt.scatter(original_x, original_y, color='black', edgecolor='green', 
            linewidth=2, s=120, zorder=10)
plt.annotate('original model', xy=(original_x, original_y), 
             xytext=(original_x+0.05, original_y+0.02),
             fontsize=12, arrowprops=dict(arrowstyle='->', color='black'))

# Set labels and title
plt.xlabel('Performance on the fine-tuning task', fontsize=16)
plt.ylabel('Safety (% of harmful queries refused)', fontsize=16)
plt.title('Safety vs Performance for different fine-tuning methods\nwith 5 intermediate checkpoints', 
          fontsize=18)

# Add a legend
legend_elements = [
    Line2D([0], [0], marker='o', color='red', label='Full-fine tuning',
           markerfacecolor='red', markersize=10),
    Line2D([0], [0], marker='o', color='gold', label='LoRA',
           markerfacecolor='gold', markersize=10),
    Line2D([0], [0], marker='o', color='green', label='RLHF',
           markerfacecolor='green', markersize=10)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=14)

# Set axis limits
plt.xlim(0, 1)
plt.ylim(0.3, 1)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

# Add a custom arrow on x and y axes
plt.annotate('', xy=(1, 0), xytext=(0, 0), 
             arrowprops=dict(arrowstyle='->', lw=2))
plt.annotate('', xy=(0, 1), xytext=(0, 0), 
             arrowprops=dict(arrowstyle='->', lw=2))

plt.tight_layout()
plt.savefig('safety_vs_performance.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate fake data for the three methods
# All methods should start from the original model point
original_x = 0.1
original_y = 0.95

# Full-fine tuning data (starting from original model point)
full_x = np.array([original_x, 0.2, 0.3, 0.5, 0.65, 0.8, 0.95])
full_y = np.array([original_y, 0.93, 0.9, 0.85, 0.75, 0.6, 0.45])

# LoRA data (starting from original model point)
lora_x = np.array([original_x, 0.25, 0.4, 0.55, 0.7, 0.85])
lora_y = np.array([original_y, 0.92, 0.88, 0.82, 0.75, 0.65])

# RLHF data (starting from original model point)
rlhf_x = np.array([original_x, 0.35, 0.5, 0.65, 0.75, 0.85, 0.95])
rlhf_y = np.array([original_y, 0.8, 0.7, 0.6, 0.55, 0.45, 0.35])

# Create figure and axis
plt.figure(figsize=(10, 8))
plt.rcParams.update({'font.size': 14})

# Use nicer colors
full_color = '#FF5733'  # A richer red
lora_color = '#FFC300'  # A richer gold/yellow
rlhf_color = '#33A852'  # A nicer green

# Plot the data points with lines
plt.plot(full_x, full_y, '-', color=full_color, linewidth=2.5, alpha=0.9)
plt.scatter(full_x[1:], full_y[1:], color=full_color, s=80, zorder=5)

plt.plot(lora_x, lora_y, '-', color=lora_color, linewidth=2.5, alpha=0.9)
plt.scatter(lora_x[1:], lora_y[1:], color=lora_color, s=80, zorder=5)

plt.plot(rlhf_x, rlhf_y, '-', color=rlhf_color, linewidth=2.5, alpha=0.9)
plt.scatter(rlhf_x[1:], rlhf_y[1:], color=rlhf_color, s=80, zorder=5)

# Plot the original model point where all three lines start
plt.scatter(original_x, original_y, color='black', s=120, zorder=10)
plt.annotate('original model', xy=(original_x, original_y), 
             xytext=(original_x+0.05, original_y),
             fontsize=12, arrowprops=dict(arrowstyle='->', color='black'))

# Set labels and title
plt.xlabel('Performance on the fine-tuning task', fontsize=16)
plt.ylabel('Safety (% of harmful queries refused)', fontsize=16)
plt.title('Safety vs Performance for different fine-tuning methods\nwith 5 intermediate checkpoints', 
          fontsize=18)

# Add a legend
legend_elements = [
    Line2D([0], [0], marker='o', color=full_color, label='Full-fine tuning',
           markerfacecolor=full_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=lora_color, label='LoRA',
           markerfacecolor=lora_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=rlhf_color, label='RLHF',
           markerfacecolor=rlhf_color, markersize=10, linewidth=2.5)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=14)

# Set axis limits
plt.xlim(0, 1)
plt.ylim(0, 100)  # Change y-axis to 0-100 scale

# Convert y-axis to percentage scale (0-100)
plt.gca().set_yticks(np.arange(0, 101, 10))
plt.gca().set_yticklabels([f"{int(x)}" for x in np.arange(0, 101, 10)])

# Rescale the y-data points to 0-100 scale
for line in plt.gca().get_lines():
    ydata = line.get_ydata()
    line.set_ydata(ydata * 100)
for collection in plt.gca().collections:
    offsets = collection.get_offsets()
    new_offsets = np.column_stack((offsets[:, 0], offsets[:, 1] * 100))
    collection.set_offsets(new_offsets)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

# Fix annotation position for original model after rescaling
original_annotation = plt.gca().texts[0]
original_annotation.set_position((original_x+0.05, original_y*100))

plt.tight_layout()
plt.savefig('safety_vs_performance.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate fake data for the three methods
# All methods should start from the original model point
original_x = 0.1
original_y = 0.95

# Full-fine tuning data (starting from original model point + 5 points)
full_x = np.array([original_x, 0.25, 0.4, 0.55, 0.7, 0.85])
full_y = np.array([original_y, 0.92, 0.90, 0.85, 0.75, 0.60])

# LoRA data (starting from original model point + 5 points)
lora_x = np.array([original_x, 0.22, 0.38, 0.55, 0.7, 0.85])
lora_y = np.array([original_y, 0.92, 0.88, 0.82, 0.75, 0.65])

# RLHF data (starting from original model point + 5 points)
rlhf_x = np.array([original_x, 0.35, 0.5, 0.65, 0.8, 0.95])
rlhf_y = np.array([original_y, 0.8, 0.7, 0.6, 0.45, 0.35])

# Create figure and axis
plt.figure(figsize=(10, 8))
plt.rcParams.update({'font.size': 14})

# Use nicer colors
full_color = '#FF5733'  # A richer red
lora_color = '#FFC300'  # A richer gold/yellow
rlhf_color = '#33A852'  # A nicer green

# Plot the data points with lines
plt.plot(full_x, full_y * 100, '-', color=full_color, linewidth=2.5, alpha=0.9)
plt.scatter(full_x[1:], full_y[1:] * 100, color=full_color, s=80, zorder=5)

plt.plot(lora_x, lora_y * 100, '-', color=lora_color, linewidth=2.5, alpha=0.9)
plt.scatter(lora_x[1:], lora_y[1:] * 100, color=lora_color, s=80, zorder=5)

plt.plot(rlhf_x, rlhf_y * 100, '-', color=rlhf_color, linewidth=2.5, alpha=0.9)
plt.scatter(rlhf_x[1:], rlhf_y[1:] * 100, color=rlhf_color, s=80, zorder=5)

# Plot the original model point where all three lines start
plt.scatter(original_x, original_y * 100, color='black', s=120, zorder=10)
plt.annotate('original model', xy=(original_x, original_y * 100), 
             xytext=(original_x+0.03, original_y * 101),
             fontsize=12)  # Removed the arrow props

# Set labels and title
plt.xlabel('Performance on the fine-tuning task', fontsize=16)
plt.ylabel('Safety (% of harmful queries refused)', fontsize=16)
plt.title('Safety vs Performance for different fine-tuning methods\nwith 5 intermediate checkpoints', 
          fontsize=18)

# Add a legend
legend_elements = [
    Line2D([0], [0], marker='o', color=full_color, label='Full-fine tuning',
           markerfacecolor=full_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=lora_color, label='LoRA',
           markerfacecolor=lora_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=rlhf_color, label='RLHF',
           markerfacecolor=rlhf_color, markersize=10, linewidth=2.5)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=14)

# Set axis limits
plt.xlim(0, 1)
plt.ylim(0, 100)  # Change y-axis to 0-100 scale

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.savefig('safety_vs_performance.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate fake data for the four methods
# All methods should start from the original model point
original_x = 0.1
original_y = 0.95

# Full-fine-tuning SFT: largest decline in safety versus high increase in fine-tuning performance
full_x = np.array([original_x, 0.25, 0.4, 0.6, 0.8, 0.95])
full_y = np.array([original_y, 0.9, 0.82, 0.7, 0.55, 0.45])

# LoRA SFT: similar to full fine-tuning but less safety degradation and less performance
lora_x = np.array([original_x, 0.22, 0.35, 0.5, 0.65, 0.8])
lora_y = np.array([original_y, 0.92, 0.85, 0.78, 0.7, 0.65])

# QLoRA SFT: even less than LoRA (both in terms of safety degradation and performance)
qlora_x = np.array([original_x, 0.2, 0.3, 0.42, 0.55, 0.65])
qlora_y = np.array([original_y, 0.93, 0.88, 0.82, 0.75, 0.7])

# DPO: safety degradation between QLora and LoRA, but performance close to full fine-tuning
dpo_x = np.array([original_x, 0.25, 0.45, 0.65, 0.8, 0.9])
dpo_y = np.array([original_y, 0.91, 0.84, 0.74, 0.65, 0.58])

# Create figure and axis
plt.figure(figsize=(10, 8))
plt.rcParams.update({'font.size': 14})

# Use distinct colors
full_color = '#FF5733'  # Reddish-orange for full fine-tuning
lora_color = '#FFC300'  # Gold for LoRA
qlora_color = '#33A852'  # Green for QLoRA
dpo_color = '#3498DB'   # Blue for DPO

# Plot the data points with lines
plt.plot(full_x, full_y * 100, '-', color=full_color, linewidth=2.5, alpha=0.9)
plt.scatter(full_x[1:], full_y[1:] * 100, color=full_color, s=80, zorder=5)

plt.plot(lora_x, lora_y * 100, '-', color=lora_color, linewidth=2.5, alpha=0.9)
plt.scatter(lora_x[1:], lora_y[1:] * 100, color=lora_color, s=80, zorder=5)

plt.plot(qlora_x, qlora_y * 100, '-', color=qlora_color, linewidth=2.5, alpha=0.9)
plt.scatter(qlora_x[1:], qlora_y[1:] * 100, color=qlora_color, s=80, zorder=5)

plt.plot(dpo_x, dpo_y * 100, '-', color=dpo_color, linewidth=2.5, alpha=0.9)
plt.scatter(dpo_x[1:], dpo_y[1:] * 100, color=dpo_color, s=80, zorder=5)

# Plot the original model point where all lines start
plt.scatter(original_x, original_y * 100, color='black', s=120, zorder=10)
plt.annotate('original model', xy=(original_x, original_y * 100), 
             xytext=(original_x+0.05, original_y * 100),
             fontsize=12)

# Set labels and title
plt.xlabel('Performance on the fine-tuning task', fontsize=16)
plt.ylabel('Safety (% of harmful queries refused)', fontsize=16)
plt.title('Safety vs Performance for different fine-tuning methods\nwith 5 intermediate checkpoints', 
          fontsize=18)

# Add a legend
legend_elements = [
    Line2D([0], [0], marker='o', color=full_color, label='Full-fine-tuning SFT',
           markerfacecolor=full_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=lora_color, label='LoRA SFT',
           markerfacecolor=lora_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=qlora_color, label='QLoRA SFT',
           markerfacecolor=qlora_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=dpo_color, label='DPO',
           markerfacecolor=dpo_color, markersize=10, linewidth=2.5)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=14)

# Set axis limits
plt.xlim(0, 1)
plt.ylim(0, 100)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.savefig('safety_vs_performance.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate fake data for the four methods
# All methods should start from the original model point
original_x = 0.1
original_y = 0.95

# Full-fine-tuning SFT: largest decline in safety versus high increase in fine-tuning performance
full_x = np.array([original_x, 0.27, 0.44, 0.63, 0.81, 0.95])
full_y = np.array([original_y, 0.89, 0.79, 0.65, 0.52, 0.42])

# LoRA SFT: similar to full fine-tuning but less safety degradation and less performance
lora_x = np.array([original_x, 0.22, 0.36, 0.52, 0.67, 0.78])
lora_y = np.array([original_y, 0.92, 0.85, 0.78, 0.71, 0.64])

# QLoRA SFT: even less than LoRA (both in terms of safety degradation and performance)
qlora_x = np.array([original_x, 0.18, 0.29, 0.41, 0.52, 0.62])
qlora_y = np.array([original_y, 0.93, 0.89, 0.84, 0.79, 0.73])

# DPO: safety degradation between QLora and LoRA, but performance close to full fine-tuning
dpo_x = np.array([original_x, 0.25, 0.47, 0.66, 0.82, 0.91])
dpo_y = np.array([original_y, 0.91, 0.82, 0.72, 0.63, 0.56])

# Create figure and axis
plt.figure(figsize=(10, 8))
plt.rcParams.update({'font.size': 14})

# Use distinct colors
full_color = '#E74C3C'  # Stronger red for full fine-tuning
lora_color = '#F39C12'  # Darker orange/amber for LoRA
qlora_color = '#27AE60'  # Deeper green for QLoRA
dpo_color = '#2980B9'   # Deeper blue for DPO

# Plot the data points with lines
plt.plot(full_x, full_y * 100, '-', color=full_color, linewidth=2.5, alpha=0.9)
plt.scatter(full_x[1:], full_y[1:] * 100, color=full_color, s=80, zorder=5)

plt.plot(lora_x, lora_y * 100, '-', color=lora_color, linewidth=2.5, alpha=0.9)
plt.scatter(lora_x[1:], lora_y[1:] * 100, color=lora_color, s=80, zorder=5)

plt.plot(qlora_x, qlora_y * 100, '-', color=qlora_color, linewidth=2.5, alpha=0.9)
plt.scatter(qlora_x[1:], qlora_y[1:] * 100, color=qlora_color, s=80, zorder=5)

plt.plot(dpo_x, dpo_y * 100, '-', color=dpo_color, linewidth=2.5, alpha=0.9)
plt.scatter(dpo_x[1:], dpo_y[1:] * 100, color=dpo_color, s=80, zorder=5)

# Plot the original model point where all lines start
plt.scatter(original_x, original_y * 100, color='black', s=120, zorder=10)
plt.annotate('original model', xy=(original_x, original_y * 100), 
             xytext=(original_x+0.05, original_y * 100),
             fontsize=12)

# Set labels and title
plt.xlabel('Performance on the fine-tuning task', fontsize=16)
plt.ylabel('Safety (% of harmful queries refused)', fontsize=16)
plt.title('Safety vs Performance for different fine-tuning methods\nwith 5 intermediate checkpoints', 
          fontsize=18)

# Add a legend
legend_elements = [
    Line2D([0], [0], marker='o', color=full_color, label='Full-fine-tuning SFT',
           markerfacecolor=full_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=lora_color, label='LoRA SFT',
           markerfacecolor=lora_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=qlora_color, label='QLoRA SFT',
           markerfacecolor=qlora_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=dpo_color, label='DPO',
           markerfacecolor=dpo_color, markersize=10, linewidth=2.5)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=14)

# Set axis limits
plt.xlim(0, 1)
plt.ylim(0, 100)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.savefig('safety_vs_performance.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate fake data for the four methods
# All methods should start from the original model point
original_x = 0.1
original_y = 0.95

# Full-fine-tuning SFT: largest decline in safety versus high increase in fine-tuning performance
full_x = np.array([original_x, 0.25, 0.42, 0.6, 0.78, 0.95])
full_y = np.array([original_y, 0.87, 0.78, 0.65, 0.52, 0.42])

# LoRA SFT: similar pattern but less safety degradation and less performance
lora_x = np.array([original_x, 0.23, 0.38, 0.55, 0.72, 0.85])
lora_y = np.array([original_y, 0.91, 0.85, 0.77, 0.68, 0.63])

# QLoRA SFT: even less than LoRA (both in terms of safety degradation and performance)
qlora_x = np.array([original_x, 0.2, 0.32, 0.45, 0.58, 0.68])
qlora_y = np.array([original_y, 0.93, 0.9, 0.86, 0.82, 0.78])

# DPO: safety degradation between QLora and LoRA, but performance close to full fine-tuning
dpo_x = np.array([original_x, 0.28, 0.48, 0.67, 0.82, 0.92])
dpo_y = np.array([original_y, 0.89, 0.81, 0.73, 0.65, 0.56])

# Create figure and axis
plt.figure(figsize=(10, 8))
plt.rcParams.update({'font.size': 14})

# Use distinct colors
full_color = '#E74C3C'  # Stronger red for full fine-tuning
lora_color = '#F39C12'  # Orange/amber for LoRA
qlora_color = '#27AE60'  # Green for QLoRA
dpo_color = '#2980B9'   # Blue for DPO

# Plot the data points with lines
plt.plot(full_x, full_y * 100, '-', color=full_color, linewidth=2.5, alpha=0.9)
plt.scatter(full_x[1:], full_y[1:] * 100, color=full_color, s=80, zorder=5)

plt.plot(lora_x, lora_y * 100, '-', color=lora_color, linewidth=2.5, alpha=0.9)
plt.scatter(lora_x[1:], lora_y[1:] * 100, color=lora_color, s=80, zorder=5)

plt.plot(qlora_x, qlora_y * 100, '-', color=qlora_color, linewidth=2.5, alpha=0.9)
plt.scatter(qlora_x[1:], qlora_y[1:] * 100, color=qlora_color, s=80, zorder=5)

plt.plot(dpo_x, dpo_y * 100, '-', color=dpo_color, linewidth=2.5, alpha=0.9)
plt.scatter(dpo_x[1:], dpo_y[1:] * 100, color=dpo_color, s=80, zorder=5)

# Plot the original model point where all lines start
plt.scatter(original_x, original_y * 100, color='black', s=120, zorder=10)
plt.annotate('original model', xy=(original_x, original_y * 100), 
             xytext=(original_x+0.05, original_y * 100),
             fontsize=12)

# Set labels and title
plt.xlabel('Performance on the fine-tuning task', fontsize=16)
plt.ylabel('Safety (% of harmful queries refused)', fontsize=16)
plt.title('Safety vs Performance for different fine-tuning methods\nwith 5 intermediate checkpoints', 
          fontsize=18)

# Add a legend
legend_elements = [
    Line2D([0], [0], marker='o', color=full_color, label='Full-fine-tuning SFT',
           markerfacecolor=full_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=lora_color, label='LoRA SFT',
           markerfacecolor=lora_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=qlora_color, label='QLoRA SFT',
           markerfacecolor=qlora_color, markersize=10, linewidth=2.5),
    Line2D([0], [0], marker='o', color=dpo_color, label='DPO',
           markerfacecolor=dpo_color, markersize=10, linewidth=2.5)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=14)

# Set axis limits
plt.xlim(0, 1)
plt.ylim(0, 100)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.savefig('safety_vs_performance.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate fake data for the four methods
# All methods should start from the original model point
original_x = 0.1
original_y = 0.95

# Full-fine-tuning SFT: largest decline in safety versus high increase in fine-tuning performance
full_x = np.array([original_x, 0.25, 0.42, 0.6, 0.78, 0.95])
full_y = np.array([original_y, 0.87, 0.78, 0.55, 0.42, 0.22])

# LoRA SFT: less performance than full fine-tuning with less safety degradation
# Make LoRA significantly different from DPO
lora_x = np.array([original_x, 0.22, 0.35, 0.5, 0.65, 0.82])
lora_y = np.array([original_y, 0.91, 0.84, 0.77, 0.68, 0.52])

# QLoRA SFT: even less than LoRA (both in terms of safety degradation and performance)
qlora_x = np.array([original_x, 0.2, 0.32, 0.45, 0.58, 0.68])
qlora_y = np.array([original_y, 0.93, 0.9, 0.82, 0.76, 0.72])

# DPO: Now with a VERY different path than LoRA
# Higher performance than LoRA with different safety trade-off pattern
dpo_x = np.array([original_x, 0.3, 0.45, 0.63, 0.8, 0.92])
dpo_y = np.array([original_y, 0.89, 0.84, 0.76, 0.73, 0.73])

# Create figure and axis
plt.figure(figsize=(10, 8))
plt.rcParams.update({'font.size': 14})

# Use distinct colors
full_color = '#E74C3C'  # Stronger red for full fine-tuning
lora_color = '#F39C12'  # Orange/amber for LoRA
qlora_color = '#27AE60'  # Green for QLoRA
dpo_color = '#2980B9'   # Blue for DPO

# Make the lines thicker and with different line styles for better distinction
plt.plot(full_x, full_y * 100, '-', color=full_color, linewidth=3.0, alpha=0.9)
plt.scatter(full_x[1:], full_y[1:] * 100, color=full_color, s=80, zorder=5)

plt.plot(lora_x, lora_y * 100, '-', color=lora_color, linewidth=3.0, alpha=0.9)
plt.scatter(lora_x[1:], lora_y[1:] * 100, color=lora_color, s=80, zorder=5)

plt.plot(qlora_x, qlora_y * 100, '-', color=qlora_color, linewidth=3.0, alpha=0.9)
plt.scatter(qlora_x[1:], qlora_y[1:] * 100, color=qlora_color, s=80, zorder=5)

plt.plot(dpo_x, dpo_y * 100, '-', color=dpo_color, linewidth=3.0, alpha=0.9)
plt.scatter(dpo_x[1:], dpo_y[1:] * 100, color=dpo_color, s=80, zorder=5)

# Plot the original model point where all lines start
plt.scatter(original_x, original_y * 100, color='black', s=120, zorder=10)
plt.annotate('original model', xy=(original_x, original_y * 100), 
             xytext=(original_x+0.03, original_y * 101),
             fontsize=12)

# Set labels and title
plt.xlabel('Performance on the fine-tuning task', fontsize=16)
plt.ylabel('Safety (% of harmful queries refused)', fontsize=16)
#plt.title('Safety vs Performance for different fine-tuning methods\nwith 5 intermediate checkpoints', 
         # fontsize=18)

# Add a legend
legend_elements = [
    Line2D([0], [0], marker='o', color=full_color, label='Full-fine-tuning',
           markerfacecolor=full_color, markersize=10, linewidth=3.0),
    Line2D([0], [0], marker='o', color=lora_color, label='LoRA',
           markerfacecolor=lora_color, markersize=10, linewidth=3.0),
    Line2D([0], [0], marker='o', color=qlora_color, label='QLoRA',
           markerfacecolor=qlora_color, markersize=10, linewidth=3.0),
    Line2D([0], [0], marker='o', color=dpo_color, label='DPO',
           markerfacecolor=dpo_color, markersize=10, linewidth=3.0)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=14)

# Set axis limits
plt.xlim(0, 1)
plt.ylim(0, 100)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.savefig('safety_vs_performance.png', dpi=300)
plt.show()
